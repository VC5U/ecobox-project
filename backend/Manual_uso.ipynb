# %% [markdown]
# # Configuración del entorno Backend Django
#
# Este notebook contiene los pasos para:
#
# - Crear un entorno virtual
# - Activarlo
# - Instalar paquetes
# - Configurar base de datos
# - Ejecutar migraciones
# - Levantar el servidor

# %% [markdown]
# Crear entorno virtual

# %%
# !python -m venv venv

# %% [markdown]
# ### Activar entorno virtual (debes hacerlo en terminal)
#
# Windows:

# %%
venv\Scripts\activate

# %% [markdown]
# Instalar paquetes

# %%
# !pip install django django-cors-headers djangorestframework djangorestframework-simplejwt pyjwt
pip install openai python-dotenv
pip install --upgrade 
pip install google-generativeai
pip install Pillow

# %%
pip install requirements.txt

# %% [markdown]
# Configurar base de datos en settings.py

# %% [markdown]
# ### Configurar la base de datos en `settings.py`
#
# Si usas SQLite no necesitas cambiar nada.
#
# #### PostgreSQL (ejemplo):
# En `settings.py`:
#
# ```python
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.postgresql',
#         'NAME': 'ecobox',
#         'USER': 'postgres',
#         'PASSWORD': 'tu_contraseña',
#         'HOST': 'localhost',
#         'PORT': '5432',
#     }
# }

# %% [markdown]
# Makemigrations

# %%
# !python manage.py makemigrations

# %% [markdown]
# Migrate

# %%
# !python manage.py migrate

# %% [markdown]
# Correr el backend

# %%
# !python manage.py runserver
